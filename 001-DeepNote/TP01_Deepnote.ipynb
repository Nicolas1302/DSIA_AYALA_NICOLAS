# %% [markdown]
# # TP01 \- Deepnote Ayala Nicolás Antonio

# %% [markdown]
# Soy Nicolás Ayala, trabajo en soporte técnico, administración de sistemas y desarrollo proyectos con Python\. Como estudiante de la Tecnicatura Superior en Ciencias de Datos e IA en el IFTS N° 24, mis expectativas para la materia son dominar estas herramientas de análisis, agilizar mis flujos de trabajo con datos y consolidar una base práctica fuerte para aplicarla en proyectos reales\.

# %%
print("Mi primer notebook en Deepnote")
# Out:
# Mi primer notebook en Deepnote

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=4cdccebd-332b-45ce-b4c9-cb4939edc6db' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
